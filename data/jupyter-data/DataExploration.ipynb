# %%
import numpy as np
import math
import csv
import glob
import imageio
import numpy as np
from mlxtend.image import extract_face_landmarks
# Out:
# Downloading http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 to /root/mlxtend_data/shape_predictor_68_face_landmarks.dat.bz2

# %%
def eye_aspect_ratio(eye):
    A = distance.euclidean(eye[1], eye[5])
    B = distance.euclidean(eye[2], eye[4])
    C = distance.euclidean(eye[0], eye[3])
    ear = (A + B) / (2.0 * C)
    return ear

def mouth_aspect_ratio(mouth):
  A = distance.euclidean(mouth[15], mouth[21])
  C = distance.euclidean(mouth[12], mouth[18])
  mar = (A ) / (C)
  return mar

def circularity(eye):
    A = distance.euclidean(eye[1], eye[4])
    radius  = A/2.0
    Area = math.pi * (radius ** 2)
    p = 0
    p += distance.euclidean(eye[0], eye[1])
    p += distance.euclidean(eye[1], eye[2])
    p += distance.euclidean(eye[2], eye[3])
    p += distance.euclidean(eye[3], eye[4])
    p += distance.euclidean(eye[4], eye[5])
    p += distance.euclidean(eye[5], eye[0])
    return 4 * math.pi * Area /(p**2)

def mouth_over_eye(eye):
    ear = eye_aspect_ratio(eye)
    mar = mouth_aspect_ratio(eye)
    mouth_eye = mar/ear
    return mouth_eye

# %%
from scipy.spatial import distance
import cv2
import os
import imageio
import matplotlib.pyplot as plt

data = []
feature=[]
img = cv2.imread('data/eye_close.jpg')
landmarks = extract_face_landmarks(img)
if landmarks is not None and sum(sum(landmarks)) != 0:
  data.append(landmarks)
  print(landmarks.shape)
else:  
  print("not detected")
data = np.array(data)
features = []
for d in data:
  eye = d[36:68]
  ear = eye_aspect_ratio(eye)
  mar = mouth_aspect_ratio(eye)
  cir = circularity(eye)
  mouth_eye = mouth_over_eye(eye)
  features.append([ear, mar, cir, mouth_eye])
features = np.array(features)

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img)
ax = fig.add_subplot(1, 3, 2)
ax.scatter(landmarks[:, 0], -landmarks[:, 1], alpha=0.8)
ax = fig.add_subplot(1, 3, 3)
img2 = img.copy()

for p in landmarks:
    img2[p[1]-3:p[1]+3, p[0]-3:p[0]+3, :] = (255, 255, 255)
    # note that the values -3 and +3 will make the landmarks
    # overlayed on the image 6 pixels wide; depending on the
    # resolution of the face image, you may want to change
    # this value

ax.imshow(img2)
# Out:
# (68, 2)

# %%
print(features)
# Out:
# [[0.16908466 0.47299862 0.36790511 2.79740711]]

# %%
data = []
feature=[]
img = cv2.imread('data/eye_close_1.jpg')
landmarks = extract_face_landmarks(img)
if landmarks is not None and sum(sum(landmarks)) != 0:
  data.append(landmarks)
  print(landmarks.shape)
else:  
  print("not detected")
data = np.array(data)
features = []
for d in data:
  eye = d[36:68]
  ear = eye_aspect_ratio(eye)
  mar = mouth_aspect_ratio(eye)
  cir = circularity(eye)
  mouth_eye = mouth_over_eye(eye)
  features.append([ear, mar, cir, mouth_eye])
features = np.array(features)

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img)
ax = fig.add_subplot(1, 3, 2)
ax.scatter(landmarks[:, 0], -landmarks[:, 1], alpha=0.8)
ax = fig.add_subplot(1, 3, 3)
img2 = img.copy()

for p in landmarks:
    img2[p[1]-3:p[1]+3, p[0]-3:p[0]+3, :] = (255, 255, 255)
    # note that the values -3 and +3 will make the landmarks
    # overlayed on the image 6 pixels wide; depending on the
    # resolution of the face image, you may want to change
    # this value

ax.imshow(img2)
# Out:
# (68, 2)

# %%
print(features)
# Out:
# [[0.18241081 0.49310442 0.32235224 2.7032632 ]]

# %%
data = []
feature=[]
img = cv2.imread('data/eye_open.jpg')
landmarks = extract_face_landmarks(img)
if landmarks is not None and sum(sum(landmarks)) != 0:
  data.append(landmarks)
  print(landmarks.shape)
else:  
  print("not detected")
data = np.array(data)
features = []
for d in data:
  eye = d[36:68]
  ear = eye_aspect_ratio(eye)
  mar = mouth_aspect_ratio(eye)
  cir = circularity(eye)
  mouth_eye = mouth_over_eye(eye)
  features.append([ear, mar, cir, mouth_eye])
features = np.array(features)

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img)
ax = fig.add_subplot(1, 3, 2)
ax.scatter(landmarks[:, 0], -landmarks[:, 1], alpha=0.8)
ax = fig.add_subplot(1, 3, 3)
img2 = img.copy()

for p in landmarks:
    img2[p[1]-3:p[1]+3, p[0]-3:p[0]+3, :] = (255, 255, 255)
    # note that the values -3 and +3 will make the landmarks
    # overlayed on the image 6 pixels wide; depending on the
    # resolution of the face image, you may want to change
    # this value

ax.imshow(img2)
print(features)
# Out:
# (68, 2)
# [[0.27819891 0.46591112 0.44697726 1.67474097]]

# %%
data = []
feature=[]
img = cv2.imread('data/mouth_open.jpg')
landmarks = extract_face_landmarks(img)
if landmarks is not None and sum(sum(landmarks)) != 0:
  data.append(landmarks)
  print(landmarks.shape)
else:  
  print("not detected")
data = np.array(data)
features = []
for d in data:
  eye = d[36:68]
  ear = eye_aspect_ratio(eye)
  mar = mouth_aspect_ratio(eye)
  cir = circularity(eye)
  mouth_eye = mouth_over_eye(eye)
  features.append([ear, mar, cir, mouth_eye])
features = np.array(features)

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img)
ax = fig.add_subplot(1, 3, 2)
ax.scatter(landmarks[:, 0], -landmarks[:, 1], alpha=0.8)
ax = fig.add_subplot(1, 3, 3)
img2 = img.copy()

for p in landmarks:
    img2[p[1]-3:p[1]+3, p[0]-3:p[0]+3, :] = (255, 255, 255)
    # note that the values -3 and +3 will make the landmarks
    # overlayed on the image 6 pixels wide; depending on the
    # resolution of the face image, you may want to change
    # this value

ax.imshow(img2)
print(features)
# Out:
# (68, 2)
# [[0.21781932 1.11265484 0.38645326 5.108155  ]]

# %%
data = []
feature=[]
img = cv2.imread('data/mouth_open_2.jpg')
landmarks = extract_face_landmarks(img)
if landmarks is not None and sum(sum(landmarks)) != 0:
  data.append(landmarks)
  print(landmarks.shape)
else:  
  print("not detected")
data = np.array(data)
features = []
for d in data:
  eye = d[36:68]
  ear = eye_aspect_ratio(eye)
  mar = mouth_aspect_ratio(eye)
  cir = circularity(eye)
  mouth_eye = mouth_over_eye(eye)
  features.append([ear, mar, cir, mouth_eye])
features = np.array(features)

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(1, 3, 1)
ax.imshow(img)
ax = fig.add_subplot(1, 3, 2)
ax.scatter(landmarks[:, 0], -landmarks[:, 1], alpha=0.8)
ax = fig.add_subplot(1, 3, 3)
img2 = img.copy()

for p in landmarks:
    img2[p[1]-3:p[1]+3, p[0]-3:p[0]+3, :] = (255, 255, 255)
    # note that the values -3 and +3 will make the landmarks
    # overlayed on the image 6 pixels wide; depending on the
    # resolution of the face image, you may want to change
    # this value

ax.imshow(img2)
print(features)
# Out:
# (68, 2)
# [[0.33202922 0.83024048 0.54875442 2.50050427]]

# %%
#EAR < 0.2 && MAR > 0.9
